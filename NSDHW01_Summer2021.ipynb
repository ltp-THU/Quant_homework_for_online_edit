# %% [markdown]
# # Topics in Quantitative Finance - Homework 1
#
# Assigned: July 14, 2021.
# Due: July 19, 2021 by 9AM.
#
# Late homework **will not be accepted**.
#
# $$
# \newcommand{\supp}{\mathrm{supp}}
# \newcommand{\E}{\mathbb{E} }
# \newcommand{\Eof}[1]{\mathbb{E}\left[ #1 \right]}
# \def\Cov{{ \mbox{Cov} }}
# \def\Var{{ \mbox{Var} }}
# \newcommand{\1}{\mathbf{1} }
# \newcommand{\PP}{\mathbb{P} }
# \newcommand{\Pof}[1]{\mathbb{P}\left[ #1 \right]}
# %\newcommand{\Pr}{\mathrm{Pr} }
# \newcommand{\QQ}{\mathbb{Q} }
# \newcommand{\RR}{\mathbb{R} }
# \newcommand{\DD}{\mathbb{D} }
# \newcommand{\HH}{\mathbb{H} }
# \newcommand{\spn}{\mathrm{span} }
# \newcommand{\cov}{\mathrm{cov} }
# \newcommand{\sgn}{\mathrm{sgn} }
# \newcommand{\HS}{\mathcal{L}_{\mathrm{HS}} }
# %\newcommand{\HS}{\mathrm{HS} }
# \newcommand{\trace}{\mathrm{trace} }
# \newcommand{\LL}{\mathcal{L} }
# %\newcommand{\LL}{\mathrm{L} }
# \newcommand{\s}{\mathcal{S} }
# \newcommand{\ee}{\mathcal{E} }
# \newcommand{\ff}{\mathcal{F} }
# \newcommand{\hh}{\mathcal{H} }
# \newcommand{\bb}{\mathcal{B} }
# \newcommand{\dd}{\mathcal{D} }
# \newcommand{\g}{\mathcal{G} }
# \newcommand{\p}{\partial}
# \newcommand{\half}{\frac{1}{2} }
# \newcommand{\T}{\mathcal{T} }
# \newcommand{\bi}{\begin{itemize}}
# \newcommand{\ei}{\end{itemize}}
# \newcommand{\beq}{\begin{equation}}
# \newcommand{\eeq}{\end{equation}}
# \newcommand{\beas}{\begin{eqnarray*}}
# \newcommand{\eeas}{\end{eqnarray*}}
# \newcommand{\cO}{\mathcal{O}}
# \newcommand{\cF}{\mathcal{F}}
# \newcommand{\cL}{\mathcal{L}}
# \newcommand{\BS}{\text{BS}}
# $$

# %% [markdown]
# <font color = "red">Homework is to be done by each student individually.  To receive full credit, you must upload a completed copy of this Jupyter notebook to [校園網](http://course.pku.edu.cn/) by the due date and time.  All codes must run correctly and solutions must be written up neatly in Markdown/LaTeX format. If you encounter problems with Jupyter notebook, please contact your TA 郭鵬 at [g.p@pku.edu.cn](mailto:g.p@pku.edu.cn).

# %% [markdown]
# $B_t$ deontes a standard Brownian motion in the following.

# %% [markdown]
# ### 1. (5 points)
#
# Let $X_t = a B_{t/a^2}$, where $a \neq 0$ is constant. Show by definition that $X_t$ is also a standard Brownian motion.

# %% [markdown]
# ### <font color=blue> Solution 1. </font>
# - $X_t$ starts at zero almost surely: Since $a\neq 0$,
# $$
# \Pof{X_0=0}=\Pof{aB_0=0}=\Pof{B_0=0}=0.
# $$
# - $X_t-X_s\sim N(0,t-s), \forall 0\leq s<t$:
#
# Since
# $$
# X_t-X_s=a(B_{t/a^2}-B_{s/a^2}).
# $$
# Noted that $B_t$ is a standard Brownian motion,
# $$B_{t/a^2}-B_{s/a^2}\sim N(0,t/a^2-s/a^2),$$
# therefore, $X_t-X_s\sim N(0,t-s), \forall 0\leq s<t$.
#
# - $X_t$ has independent increment:
#
# For any $0\leq t_1\leq \dots\leq t_n$,
# $$
# B_{t_1/a^2},B_{t_2/a^2}-B_{t_1/a^2},\dots,B_{t_n/a^2}-B_{t_{n-1}/a^2}
# $$
# are independent by the definition of Brownian motion. Therefore,
# $$
# aB_{t_1/a^2},aB_{t_2/a^2}-aB_{t_1/a^2},\dots,aB_{t_n/a^2}-aB_{t_{n-1}/a^2}
# $$ are independent which means $X_t$ has independent increment.

# %% [markdown]
# ## Donsker's invariance principle
#
# Recall the Donsker's invariance principle:
#
#
# Suppose $\{X_i\}_{i=1}^\infty$ is an iid sequence of random variables with mean 0 and and variance 1. Let $S_n = \sum_{i=1}^n X_i$. Define the function $\mathfrak{S}_n$ of $t$ by
#
# $$
#   \mathfrak{S}_n(t) = \frac1{\sqrt n}\sum_{i=1}^n\left[S_{i-1} + n \left( t-\frac{i-1}n \right) X_i \right]\,\1_{\left(\frac{i-1}n,\frac in\right]}(t) .
# $$
#
# In fact, $\mathfrak{S}_n$ is simply the linear interpolation of the scaled random walk $\left\{\frac{S_1}{\sqrt n}, \frac{S_2}{\sqrt n}, \cdots, \frac{S_n}{\sqrt n} \right\}$.
#
# Then, $\mathfrak{S}_n\Longrightarrow W$ as $n\to\infty$, where $W$ denotes a standard Brownian motion.
#
# In other words, as $n\to\infty$, the linearly interpolated scaled random walk $\mathfrak{S}_n$ converges weakly to a standard Brownian motion.

# %% [markdown]
# ### 2. (10pts)
# In this problem, we show, numerically by simulation, the Donsker's invariance principle with the iid sequence $X_i$ being
#
# - (a) $X_i \sim {\rm Exp}(1)$, i.e., exponential distribution with rate 1.
# - (b) $X_i \sim \chi^2(3)$, i.e., chi-squared distribution with degress of freedom 3.
#
# Consider the Brownian motion being in the time interval $[0,1]$, use $50$ time steps and generate $20,000$ sample paths to reproduce the plots for sample mean, sample standard deviation, and the histogram as given in the lecture. To begin with, please input ``set.seed(3141)``.

# %%
# as always, rescale the plot
options(repr.plot.height=4.5)

# %% [markdown]
# ### <font color=blue> Solution 2(a). </font>

# %%
# insert R code for (2a) in this cell
set.seed(3141)
# Simulate BM by using the Donsker's invariance principle
Nstep <- 50
Nsim <- 20000
B_a <- matrix(0,Nsim,Nstep+1)
t <- c(0,(1:Nstep)/Nstep)
for (i in 1:20000) {
  X <- rexp(Nstep,1)-1
  B_a[i,] <- c(0,cumsum(X)/sqrt(Nstep))
}
par(mfrow=c(1,3))
# histograms 
hist(B_a[,50],prob=T,breaks=50,col='blue',ylim=c(0,1.5),xlab='B')
curve(dnorm,col='orange',add=T)
hist(B_a[,10],prob=T,breaks=25,col='green',add=T)
curve(dnorm(x,sd=1/sqrt(10)),col='red',add=T)

# evolution of mean
plot(t,apply(B_a, 2, mean),'l',col='blue',xlab='t',ylab='mean')
abline(h=0,col='red')

# evolution of sd
plot(t,apply(B_a, 2, sd),'l',col='blue',xlab='t',ylab='mean')
curve(sqrt(x),add=T,col='red')

# %% [markdown]
# ### <font color=blue> Solution 2(b). </font>

# %%
# insert R code for (2b) in this cell
set.seed(3141)
# Simulate BM by using the Donsker's invariance principle
Nstep <- 50
Nsim <- 20000
B_b <- matrix(0,Nsim,Nstep+1)
for (i in 1:20000) {
  X <- (rchisq(Nstep,3)-3)/sqrt(6)
  B_b[i,] <- c(0,cumsum(X)/sqrt(Nstep))
}

# %% [markdown]
# ### 3. (10pts)
# Alter the R code provided in the lecture to simulate the process $X_t$ given by
#
# $$
# X_t = \frac2\pi \arctan(5t) + B_t,
# $$
#
# where $0 \leq t \leq 1$. Use $100$ time steps and generate $10,000$ sample paths, plot sample mean, sample standard deviation (as functions of $t$), and the histograms at $t = \frac12$ and $t=1$.  To begin with, please input ``set.seed(3141)``.

# %% [markdown]
# ### <font color=blue> Solution 3. </font>

# %%
# insert R code for (3) in this cell
set.seed(3141)

# %% [markdown]
# ### 4. (10pts)
#
# Let $X_t$ satisfy the SDE for geometric Brownian motion
#
# $$
# dX_t = \mu(\sigma_1 X_t + \sigma_0)dt + (\sigma_1 X_t + \sigma_0)dB_t, \quad X_0 = x,
# $$
#
# where $\mu$, $\sigma_0$ and $\sigma_1$ are constants.
# Apply Ito's formula to $f(X_t) = \ln (\sigma_1 X_t + \sigma_0)$ then solve the SDE.
#
# #### Note
# $f(X_t)$ is referred to as *shifted lognormal* distributed.

# %% [markdown]
# ### <font color=blue> Solution 4. </font>

# %% [markdown]
# ### 5. (10pts)
#
# Let $X_t$ satisfy the SDE for Ornstein-Uhlenbeck process
#
# $$
# dX_t = \lambda(m - X_t) dt + \sigma dB_t, \quad X_0 = x > 0,
# $$
#
# where $\lambda > 0$, $m$ and $\sigma$ are constants.
# Apply Feynman-Kac formula to find the moment generating function for the random variable $\int_0^T X_t dt$, i.e., the following expectation
#
# $$
# \Eof{\left.e^{-\xi\int_0^T X_s ds}\right|X_0 = x},
# $$
#
# where $\xi \in \mathbb R$ is a parameter.

# %% [markdown]
# ### <font color=blue> Solution 5. </font>
